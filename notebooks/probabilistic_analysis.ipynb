# %% [markdown]
# # Probabilistic Analysis
#
# This notebook reruns Bayesian updates and Monte Carlo uncertainty propagation. Outputs are exploratory stress-test diagnostics, not calibrated geopolitical probabilities.

# %%
from pathlib import Path
import subprocess
import sys
import pandas as pd
from IPython.display import Image, Markdown, display

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
TABLES = PROJECT_ROOT / "reports" / "tables" / "probabilistic"
FIGURES = PROJECT_ROOT / "reports" / "figures" / "probabilistic"

# %%
subprocess.run([sys.executable, str(PROJECT_ROOT / "scripts" / "run_bayesian_updates.py")], cwd=PROJECT_ROOT, check=True)
subprocess.run([sys.executable, str(PROJECT_ROOT / "scripts" / "run_monte_carlo.py"), "--iterations", "100"], cwd=PROJECT_ROOT, check=True)

# %%
display(pd.read_csv(TABLES / "bayesian_diagnostics.csv"))
display(pd.read_csv(TABLES / "monte_carlo_diagnostics.csv"))
display(pd.read_csv(TABLES / "sensitivity_rankings.csv").head(12))

# %%
for figure in [
    FIGURES / "posterior_distributions.png",
    FIGURES / "scenario_probability_evolution.png",
    FIGURES / "uncertainty_fan_economic_output_proxy.png",
    FIGURES / "sensitivity_tornado_ai_capability_divergence.png",
]:
    if figure.exists():
        display(Image(filename=str(figure)))

# %%
path = PROJECT_ROOT / "reports" / "probabilistic_methodology.md"
if path.exists():
    display(Markdown(path.read_text()))
